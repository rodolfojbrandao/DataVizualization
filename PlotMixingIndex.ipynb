# %%
import os
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
from multiprocessing import Pool
import statsmodels.api as sm
import statsmodels.formula.api as smf # pacotes estatisticos
from scipy.optimize import curve_fit
import sympy as sym

# %%
# !git clone http://github.com/rodolfojbrandao/PhD/Resultados/segregacao-efeito-combinado-tamanho-densidade
# %cd segregacao-efeito-combinado-tamanho-densidade
# !ls

# %%
i=0
j=3
Dados = pd.read_csv('dados{}{}.csv'.format(i,j))
x = Dados.iloc[0:490,0]
y = Dados.iloc[0:490,4]
x = np.array(x, dtype=float) #transform your data in a numpy array of floats 
y = np.array(y, dtype=float) #so the curve_fit can work
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-39055058666f> in <module>()
#       1 i=0
#       2 j=3
# ----> 3 Dados = pd.read_csv('dados{}{}.csv'.format(i,j))
#       4 x = Dados.iloc[0:490,0]
#       5 y = Dados.iloc[0:490,4]
#
# ...

# %%
#plt.plot(x,y)
#plt.ylabel('time (s)')
#plt.xlabel('M ( - )')
#plt.title('Dados {}{}'.format(i,j))
#plt.show()

# %%
def func(x,k,c):
    return (0.5-c)*np.exp(-k*x)+c

popt, pcov = curve_fit(func,x,y)

# %%
print(popt)

# %%
print ("k = %s, c = %s" % (popt[0], popt[1]))
# Out:
# k = 0.18003057816771317, c = 0.23831376421252773

# %%
plt.figure()
plt.plot(x, y, 'k-', label="Original Data")
plt.plot(x, func(x, *popt), 'r-', label="Fitted Curve")
plt.legend()
plt.show()
